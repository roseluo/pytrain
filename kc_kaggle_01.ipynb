# %% [markdown]
# # king of county 01
#
# *[https://www.kaggle.com/beesent/70-house-price-prediction-in-king-county-usa]*

# %%
import pandas as pd

housing_data=pd.read_csv("input/kc_train.csv", header=None)

features=['date','price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','grade','sqft_above','sqft_basement','yr_built','yr_renovated','lat','long','distance']

housing_data.columns=features

price=housing_data['price']

housing_data.head()
# Out:
#        date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20150302  545000         3       2.25         1670      6240     1.0
# 1  20150211  785000         4       2.50         3300     10514     2.0
# 2  20150107  765000         3       3.25         3190      5283     2.0
# 3  20141103  720000         5       2.50         2900      9525     2.0
# 4  20140603  449500         5       2.75         2040      7488     1.0
#
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated      lat     long  \
# 0      8        1240            430      1974             0  47.6413 -122.113
# 1     10        3300              0      1984             0  47.6323 -122.036
# 2      9        3190              0      2007             0  47.5534 -122.002
# 3      9        2900              0      1989             0  47.5442 -122.138
# 4      7        1200            840      1969             0  47.7289 -122.172
#
#        distance
# 0  13558.890160
# 1  17286.596180
# ...

# %%
data=housing_data.drop(['date', 'price'])

# %%
from sklearn.cross_validation import train_test_split

x_train, x_test, y_train, y_test=train_test_split(housing_data, price, train_size=0.8, random_state=0)

from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
sc.fit(x_train)

x_train_std=sc.transform(x_train)
x_test_std=sc.transform(x_test)

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

models=[LinearRegression(),
       RandomForestRegressor(n_estimators=100, max_features='sqrt'),
       KNeighborsRegressor(n_neighbors=6),
       SVR(kernel='linear'),
       ]

#train_results=[]

for model in models:
    model.fit(x_train_std, y_train)
    y_train_pred=model.predict(x_train_std)
    y_test_pred=model.predict(x_test_std)
    #train_results.append([model, y_train_pred, y_test_pred])
    accuracy=model.score(x_test_std, y_test)
    print("Accuracy: {}%".format(int(round(accuracy*100))))
# Out:
# Accuracy: 100%
# Accuracy: 97%
# Accuracy: 93%
# Accuracy: 2%
